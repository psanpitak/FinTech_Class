# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

load_dotenv()
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\P\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
# YOUR CODE HERE!
from newsapi import NewsApiClient
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
# YOUR CODE HERE!
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_article = newsapi.get_everything(q="Bitcoin", language="en", page_size=100, sort_by="relevancy")
print(f"Total articles about Bitcoin: {btc_article['totalResults']}")
# Out:
# Total articles about Bitcoin: 9411

# %%
# Fetch the Ethereum news articles
# YOUR CODE HERE!
eth_article = newsapi.get_everything(q="Ethereum", language="en", page_size=100, sort_by="relevancy")
print(f"Total articles about Ethereum: {eth_article['totalResults']}")
# Out:
# Total articles about Ethereum: 1847

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!

btc_sentiments = []

for article in btc_article["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-02-08  Elon Musks cryptocurrency hype was more than j...    0.3182
# 1  2021-02-09  Tesla, led by Elon Musk, confirmed that it pur...    0.3818
# 2  2021-02-09  For a brief moment on Sunday, before Tesla sai...   -0.1027
# 3  2021-02-12  Twitter and Square CEO Jack Dorsey and rapper ...    0.2500
# 4  2021-02-08  Today in an SEC filing, Tesla disclosed that i...    0.6597
#
#    positive  negative  neutral
# 0     0.091     0.000    0.909
# 1     0.071     0.000    0.929
# 2     0.000     0.038    0.962
# 3     0.056     0.000    0.944
# 4     0.137     0.000    0.863

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!

eth_sentiments = []

for article in eth_article["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-02-18  Worried that the GeForce RTX 3060 will be sold...   -0.3400
# 1  2021-03-06  NFTs are the latest cryptocurrency rage these ...   -0.4588
# 2  2021-02-27  NFTs (non-fungible tokens) — or scarce digital...    0.4404
# 3  2021-02-20  While the first Christie's auction of digital ...    0.0258
# 4  2021-02-18  Attempting to get ahead of cryptocurrency mine...    0.7096
#
#    positive  negative  neutral
# 0     0.063     0.119    0.818
# 1     0.066     0.145    0.789
# 2     0.091     0.000    0.909
# 3     0.030     0.000    0.970
# 4     0.144     0.000    0.856

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  94.000000  94.000000  94.000000  94.000000
# mean    0.183196   0.066043   0.021426   0.901872
# std     0.354427   0.066057   0.052181   0.125229
# min    -0.906200   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.857750
# 50%     0.102700   0.057500   0.000000   0.929000
# 75%     0.440400   0.102500   0.000000   0.993250
# max     0.851900   0.260000   0.326000   1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  91.000000  91.000000  91.000000  91.000000
# mean    0.172741   0.070758   0.029000   0.900242
# std     0.409154   0.072954   0.049547   0.077715
# min    -0.709600   0.000000   0.000000   0.667000
# 25%     0.000000   0.000000   0.000000   0.852000
# 50%     0.140600   0.066000   0.000000   0.909000
# 75%     0.526700   0.114000   0.061000   0.958000
# max     0.900100   0.333000   0.160000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
# YOUR CODE HERE!
sw = set(stopwords.words('english'))
# Expand the default stopwords list if necessary
# YOUR CODE HERE!
sw_addon = {'said', 'mln', 'kilolitres','kl'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    result1 = [lemmatizer.lemmatize(word) for word in words]
    
    # Convert the words to lowercase
    result2 = [word.lower() for word in result1]
        
    # Remove the stop words
    tokens = [word.lower() for word in result2 if word.lower() not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
btc_df["token"] = [tokenizer(i) for i in btc_df["text"]]
btc_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-02-08  Elon Musks cryptocurrency hype was more than j...    0.3182
# 1  2021-02-09  Tesla, led by Elon Musk, confirmed that it pur...    0.3818
# 2  2021-02-09  For a brief moment on Sunday, before Tesla sai...   -0.1027
# 3  2021-02-12  Twitter and Square CEO Jack Dorsey and rapper ...    0.2500
# 4  2021-02-08  Today in an SEC filing, Tesla disclosed that i...    0.6597
#
#    positive  negative  neutral  \
# 0     0.091     0.000    0.909
# 1     0.071     0.000    0.929
# 2     0.000     0.038    0.962
# 3     0.056     0.000    0.944
# 4     0.137     0.000    0.863
#
#                                                token
# 0  [elon, musks, cryptocurrency, hype, wa, idle, ...
# 1  [tesla, led, elon, musk, confirmed, purchased,...
# 2  [brief, moment, sunday, tesla, invested, billi...
# 3  [twitter, square, ceo, jack, dorsey, rapper, j...
# 4  [today, sec, filing, tesla, disclosed, ha, acq...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_df["token"] = [tokenizer(i) for i in eth_df["text"]]
eth_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-02-18  Worried that the GeForce RTX 3060 will be sold...   -0.3400
# 1  2021-03-06  NFTs are the latest cryptocurrency rage these ...   -0.4588
# 2  2021-02-27  NFTs (non-fungible tokens) — or scarce digital...    0.4404
# 3  2021-02-20  While the first Christie's auction of digital ...    0.0258
# 4  2021-02-18  Attempting to get ahead of cryptocurrency mine...    0.7096
#
#    positive  negative  neutral  \
# 0     0.063     0.119    0.818
# 1     0.066     0.145    0.789
# 2     0.091     0.000    0.909
# 3     0.030     0.000    0.970
# 4     0.144     0.000    0.856
#
#                                                token
# 0  [worried, geforce, rtx, sold, cryptocurrency, ...
# 1  [nfts, latest, cryptocurrency, rage, day, band...
# 2  [nfts, nonfungible, token, scarce, digital, co...
# 3  [first, christies, auction, digital, artwork, ...
# 4  [attempting, get, ahead, cryptocurrency, miner...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
import numpy as np
btc_token = np.concatenate([np.ravel(i) for i in btc_df["token"]])
btc_bigram_counts = Counter(ngrams(btc_token, n=2))
btc_bigram_counts.most_common(10)
# Out:
# [(('char', 'reuters'), 25),
#  (('virtual', 'currency'), 11),
#  (('reuters', 'stafffile'), 10),
#  (('stafffile', 'photo'), 10),
#  (('illustration', 'taken'), 10),
#  (('reuters', 'bitcoin'), 10),
#  (('record', 'high'), 9),
#  (('billion', 'bitcoin'), 8),
#  (('elon', 'musk'), 6),
#  (('tesla', 'inc'), 6)]

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
eth_token = np.concatenate([np.ravel(i) for i in eth_df["token"]])
eth_bigram_counts = Counter(ngrams(eth_token, n=2))
eth_bigram_counts.most_common(10)
# Out:
# [(('char', 'reuters'), 15),
#  (('record', 'high'), 12),
#  (('feb', 'reuters'), 9),
#  (('char', 'new'), 9),
#  (('new', 'york'), 9),
#  (('reuters', 'stafffile'), 7),
#  (('stafffile', 'photo'), 7),
#  (('char', 'dollar'), 7),
#  (('reuters', 'bitcoin'), 7),
#  (('graphic', 'world'), 7)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
token_count(btc_token,10)
# Out:
# [('char', 91),
#  ('bitcoin', 74),
#  ('reuters', 47),
#  ('ha', 24),
#  ('cryptocurrency', 19),
#  ('tesla', 19),
#  ('currency', 18),
#  ('photo', 17),
#  ('high', 16),
#  ('market', 14)]

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
token_count(eth_token,10)
# Out:
# [('char', 91),
#  ('reuters', 44),
#  ('bitcoin', 37),
#  ('new', 27),
#  ('cryptocurrency', 23),
#  ('ethereum', 20),
#  ('high', 20),
#  ('dollar', 18),
#  ('ha', 15),
#  ('us', 15)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
btc_big_string = ' '.join(btc_token)
btc_wc = WordCloud().generate(btc_big_string)
plt.imshow(btc_wc)

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
eth_big_string = ' '.join(eth_token)
eth_wc = WordCloud().generate(eth_big_string)
plt.imshow(eth_wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
btc_corpus = ' '.join(btc_df['text'])

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
btc_doc = nlp(btc_corpus)
# Add a title to the document
# YOUR CODE HERE!
btc_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Elon Musks cryptocurrency hype was more than just idle talk. CNBCreports that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  not only bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of Bitcoin to help diversify and maximize its returns, but will start taking pay… [+1182 chars] Tesla, led by
# ...

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in btc_doc.ents])
# Out:
# ['Tesla', '$1.5 billion', 'Elon Musk', 'about $ 1.5 billion', 'January', 'Artur', 'Widak', 'NurPhoto', 'Sunday', 'Tesla', '$1.5 billion', 'Jack Dorsey', 'Jay Z', 'Africa', 'India', 'Dorsey', 'Friday', '500', 'Today', 'SEC', 'Tesla', '$1.5 billion', 'first', 'more than a decade later', 'Feb. 9, 2021', '8:01 a.m.', 'Feb. 9, 2021', '8:01 a.m.', 'Bitcoin', 'Teslas', 'Monday', '1.5', 'Coinbase', 'San Francisco', 'last year', 'Thursday', 'this morning', 'over $50,000', 'Francis Suarez', 'Jack Dorsey', 'Jay Z', 'Datadog', 'Startup Battlefield', 'BuzzFeed', 'AI', 'Daily Crunch', 'February 12, 2021', 'Bitcoins', 'recent weeks', 'Friday', 'over $12,000', 'New York', 'CNN', 'above $58,000', 'Sunday', 'just above $46,000', 'Tuesday', '6', 'Alabamas', 'Richard Shelby', 'next year', 'Shelby', '86', 'seventh', 'DoorDash', 'Tesla', 'Daily Crunch', 'February 8, 2021', 'DoorDash', 'Blockchain.com', '$120 million', 'Moore Strategic Ventu', 'This morning', 'Coinbase', 'American', 'Reuters', 'FILE', 'Bit
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
eth_corpus = ' '.join(eth_df['text'])

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
eth_doc = nlp(eth_corpus)
# Add a title to the document
# YOUR CODE HERE!
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Worried that the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GeForce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  RTX
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3060
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will be sold out as cryptocurrency miners snap up every
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GPU
# ...

# %%
# List all Entities
# YOUR CODE HERE!
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Worried that the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GeForce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  RTX
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3060
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will be sold out as cryptocurrency miners snap up every
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GPU
# ...

# %% [markdown]
# ---
